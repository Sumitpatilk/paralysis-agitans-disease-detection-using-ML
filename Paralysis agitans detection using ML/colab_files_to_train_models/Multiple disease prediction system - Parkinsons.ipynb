# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection & Analysis

# %%
# loading the data from csv file to a Pandas DataFrame
parkinsons_data = pd.read_csv('F:\multiple-disease-prediction-streamlit-app-main\dataset\parkinsons.csv')

# %%
# printing the first 5 rows of the dataframe
parkinsons_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S05_4      153.880       172.860        78.128         0.00480
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00003   0.00232   0.00267     0.00696       0.04137  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.06062  0.01849  19.493       1  0.629017  0.698951 -5.186960
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.237622  2.557536  0.259765
#
# [5 rows x 24 columns]

# %%
# number of rows and columns in the dataframe
parkinsons_data.shape
# Out:
# (71, 24)

# %%
# getting more information about the dataset
parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              71 non-null     object
#  1   MDVP:Fo(Hz)       71 non-null     float64
#  2   MDVP:Fhi(Hz)      71 non-null     float64
#  3   MDVP:Flo(Hz)      71 non-null     float64
#  4   MDVP:Jitter(%)    71 non-null     float64
#  5   MDVP:Jitter(Abs)  71 non-null     float64
#  6   MDVP:RAP          71 non-null     float64
#  7   MDVP:PPQ          71 non-null     float64
#  8   Jitter:DDP        71 non-null     float64
#  9   MDVP:Shimmer      71 non-null     float64
#  10  MDVP:Shimmer(dB)  71 non-null     float64
#  11  Shimmer:APQ3      71 non-null     float64
#  12  Shimmer:APQ5      71 non-null     float64
#  13  MDVP:APQ          71 non-null     float64
#  14  Shimmer:DDA       71 non-null     float64
#  15  NHR               71 non-null     float64
#  16  HNR               71 non-null     float64
#  17  status            71 non-null     int64
#  18  RPDE              71 non-null     float64
#  19  DFA               71 non-null     float64
#  20  spread1           71 non-null     float64
#  21  spread2           71 non-null     float64
#  22  D2                71 non-null     float64
#  23  PPE               71 non-null     float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 13.4+ KB

# %%
# checking for missing values in each column
parkinsons_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# getting some statistical measures about the data
parkinsons_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count    71.000000     71.000000     71.000000       71.000000
# mean    161.617704    201.596211    123.436958        0.005080
# std      44.276070     84.176544     50.722795        0.002634
# min     104.400000    119.167000     65.476000        0.001780
# 25%     120.035000    141.118000     83.958500        0.002925
# 50%     148.790000    192.921000    108.153000        0.004420
# 75%     200.346000    236.056500    144.761000        0.007335
# max     252.455000    592.030000    232.483000        0.013600
#
#        MDVP:Jitter(Abs)   MDVP:RAP   MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count         71.000000  71.000000  71.000000   71.000000     71.000000
# mean           0.000036   0.002521   0.002825    0.007564      0.023894
# std            0.000024   0.001371   0.001591    0.004112      0.012356
# min            0.000007   0.000920   0.001060    0.002760      0.009540
# 25%            0.000015   0.001435   0.001605    0.004305      0.016105
# 50%            0.000030   0.002060   0.002340    0.006190      0.019090
# 75%            0.000050   0.003505   0.003825    0.010510      0.029190
# max            0.000090   0.006470   0.007810    0.019410      0.061340
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA        NHR        HNR     status  \
# count         71.000000  ...    71.000000  71.000000  71.000000  71.000000
# mean           0.224028  ...     0.037939   0.014090  23.720915   0.492958
# std            0.119824  ...     0.020751   0.016921   3.221706   0.503509
# min            0.085000  ...     0.014030   0.000650  17.883000   0.000000
# 25%            0.142500  ...     0.024045   0.004775  21.315500   0.000000
# 50%            0.185000  ...     0.030390   0.007860  23.216000   0.000000
# 75%            0.270500  ...     0.048630   0.017940  25.398500   1.000000
# max            0.626000  ...     0.100700   0.107150  33.047000   1.000000
#
#             RPDE        DFA    spread1    spread2         D2        PPE
# count  71.000000  71.000000  71.000000  71.000000  71.000000  71.000000
# mean    0.464331   0.721108  -6.141041   0.188755   2.256955   0.171178
# std     0.092484   0.058389   1.050516   0.068644   0.310919   0.083766
# min     0.256570   0.623731  -7.964984   0.006274   1.423287   0.044539
# 25%     0.408083   0.671601  -6.981070   0.152377   2.056539   0.104777
# 50%     0.458359   0.726652  -6.277170   0.196102   2.277927   0.147403
# 75%     0.536636   0.761435  -5.496274   0.228691   2.453927   0.217737
# max     0.663842   0.825288  -3.583722   0.335590   2.916777   0.368975
#
# [8 rows x 23 columns]

# %%
# distribution of target Variable
parkinsons_data['status'].value_counts()
# Out:
# status
# 0    36
# 1    35
# Name: count, dtype: int64

# %% [markdown]
# 1  --> Parkinson's Positive
#
# 0 --> Healthy

# %%
# grouping the data bas3ed on the target variable
# parkinsons_data.groupby('status').mean()

# %% [markdown]
# Data Pre-Processing

# %% [markdown]
# Separating the features & Target

# %%
X = parkinsons_data.drop(columns=['name','status'], axis=1)
Y = parkinsons_data['status']

# %%
print(X)
# Out:
#     MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0       119.992       157.302        74.997         0.00784           0.00007
# 1       122.400       148.650       113.819         0.00968           0.00008
# 2       116.682       131.111       111.555         0.01050           0.00009
# 3       116.676       137.871       111.366         0.00997           0.00009
# 4       153.880       172.860        78.128         0.00480           0.00003
# ..          ...           ...           ...             ...               ...
# 66      174.188       230.978        94.261         0.00459           0.00003
# 67      209.516       253.017        89.488         0.00564           0.00003
# 68      174.688       240.005        74.287         0.01360           0.00008
# 69      198.764       396.961        74.904         0.00740           0.00004
# 70      214.289       260.277        77.973         0.00567           0.00003
#
#     MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0    0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1    0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2    0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3    0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4    0.00232   0.00267     0.00696       0.04137             0.370  ...
# ..       ...       ...         ...           ...               ...  ...
# 66   0.00263   0.00259     0.00790       0.04087             0.405  ...
# 67   0.00331   0.00292     0.00994       0.02751             0.263  ...
# 68   0.00624   0.00564     0.01873       0.02308             0.256  ...
# 69   0.00370   0.00390     0.01109       0.02296             0.241  ...
# 70   0.00295   0.00317     0.00885       0.01884             0.190  ...
#
#     MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# 0    0.02971      0.06545  0.02211  21.033  0.414783  0.815285 -4.813031
# 1    0.04368      0.09403  0.01929  19.085  0.458359  0.819521 -4.075192
# 2    0.03590      0.08270  0.01309  20.651  0.429895  0.825288 -4.443179
# 3    0.03772      0.08771  0.01353  20.644  0.434969  0.819235 -4.117501
# 4    0.04525      0.06062  0.01849  19.493  0.629017  0.698951 -5.186960
# ..       ...          ...      ...     ...       ...       ...       ...
# 66   0.02745      0.07008  0.02764  19.517  0.448439  0.657899 -6.538586
# 67   0.01879      0.04812  0.01810  19.147  0.431674  0.683244 -6.195325
# 68   0.01667      0.03804  0.10715  17.883  0.407567  0.655683 -6.787197
# 69   0.01588      0.03794  0.07223  19.020  0.451221  0.643956 -6.744577
# 70   0.01373      0.03078  0.04398  21.209  0.462803  0.664357 -5.724056
#
#      spread2        D2       PPE
# 0   0.266482  2.301442  0.284654
# 1   0.335590  2.486855  0.368674
# 2   0.311173  2.342259  0.332634
# 3   0.334147  2.405554  0.368975
# 4   0.237622  2.557536  0.259765
# ..       ...       ...       ...
# 66  0.121952  2.657476  0.133050
# 67  0.129303  2.784312  0.168895
# 68  0.158453  2.679772  0.131728
# 69  0.207454  2.138608  0.123306
# 70  0.190667  2.555477  0.148569
#
# [71 rows x 22 columns]

# %%
print(Y)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 66    0
# 67    0
# 68    0
# 69    0
# 70    0
# Name: status, Length: 71, dtype: int64

# %% [markdown]
# Splitting the data to training data & Test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (71, 22) (56, 22) (15, 22)

# %% [markdown]
# Model Training

# %% [markdown]
# Support Vector Machine Model

# %%
model = svm.SVC(kernel='linear')

# %%
# training the SVM model with training data
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy score on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)

# %%
print('Accuracy score of training data : ', training_data_accuracy)
# Out:
# Accuracy score of training data :  0.9107142857142857

# %%
# accuracy score on training data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)

# %%
print('Accuracy score of test data : ', test_data_accuracy)
# Out:
# Accuracy score of test data :  0.7333333333333333

# %% [markdown]
# Building a Predictive System

# %%
input_data = (197.07600,206.89600,192.05500,0.00289,0.00001,0.00166,0.00168,0.00498,0.01098,0.09700,0.00563,0.00680,0.00802,0.01689,0.00339,26.77500,0.422229,0.741367,-7.348300,0.177551,1.743867,0.085569)

# changing input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)


if (prediction[0] == 0):
  print("The Person does not have Parkinsons Disease")

else:
  print("The Person has Parkinsons")
# Out:
# [0]
# The Person does not have Parkinsons Disease
# c:\Users\Admin\anaconda3\envs\my_env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Saving the trained model

# %%
import pickle

# %%
import pickle
filename = 'parkinsons_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
# loading the saved model
loaded_model = pickle.load(open('parkinsons_model.sav', 'rb'))

# %%
for column in X.columns:
  print(column)
# Out:
# MDVP:Fo(Hz)
# MDVP:Fhi(Hz)
# MDVP:Flo(Hz)
# MDVP:Jitter(%)
# MDVP:Jitter(Abs)
# MDVP:RAP
# MDVP:PPQ
# Jitter:DDP
# MDVP:Shimmer
# MDVP:Shimmer(dB)
# Shimmer:APQ3
# Shimmer:APQ5
# MDVP:APQ
# Shimmer:DDA
# NHR
# HNR
# RPDE
# DFA
# spread1
# spread2
# D2
# PPE
